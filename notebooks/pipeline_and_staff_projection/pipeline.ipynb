# %% [markdown]
# To begin a new project, first create a folder to contain the project files.
# Next, open PyCharm and start a new project within that folder.
# Create a Python Notebook (.ipynb) file to serve as the IDE
# Create new Python (.py) files as needed.

# %% [markdown]
# To install a package, open the Anaconda Prompt and use conda install package name

# %% [markdown]
# If desired, create a virtual environment within the project's folder as well

# %% [markdown]
# Data inputs for
