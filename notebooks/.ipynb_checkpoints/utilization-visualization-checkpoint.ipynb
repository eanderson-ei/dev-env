# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import random

# %%
# %matplotlib inline

# %%
employees = ['EA', 'KR', 'KB', 'CP', 'MM', 'MC']
targets = [65, 45, 85, 45, 85, 70]
months = ['April', 'May', 'June', 'July', 'August', 'September', 'October', 'November',
         'December', 'January', 'February', 'March']

# %%
df = pd.DataFrame(list(zip(employees, targets)), columns=['Employees', months[0]])
df.set_index('Employees', inplace=True)
df
# Out:
#            April
# Employees
# EA            65
# KR            45
# KB            85
# CP            45
# MM            85
# MC            70

# %%
for month in months[1:-5]:
    random_data = [random.randrange(60,140)/100 for employee in df.index]
    df[month] = df['April'] * random_data
df
# Out:
#            April     May   June    July  August  September  October
# Employees
# EA            65   39.00  53.95   89.05   48.75      80.60    39.65
# KR            45   50.85  36.45   53.55   45.90      39.15    56.70
# KB            85   95.20  69.70  103.70   90.95      90.95    89.25
# CP            45   28.80  28.35   27.45   35.10      61.65    29.25
# MM            85  118.15  51.00  102.85   98.60     111.35    74.80
# MC            70   74.90  43.40   82.60   58.10      90.30    91.70

# %%
df.T.plot(legend=False)

# %%
habitat_avg = df.loc[['EA', 'KR', 'KB']].mean()
habitat_avg
# Out:
# April        65.000000
# May          61.683333
# June         53.366667
# July         82.100000
# August       61.866667
# September    70.233333
# October      61.866667
# dtype: float64

# %%
df.loc['Habitat'] = habitat_avg.T
df
# Out:
#            April         May       June    July     August   September  \
# Employees
# EA          65.0   39.000000  53.950000   89.05  48.750000   80.600000
# KR          45.0   50.850000  36.450000   53.55  45.900000   39.150000
# KB          85.0   95.200000  69.700000  103.70  90.950000   90.950000
# CP          45.0   28.800000  28.350000   27.45  35.100000   61.650000
# MM          85.0  118.150000  51.000000  102.85  98.600000  111.350000
# MC          70.0   74.900000  43.400000   82.60  58.100000   90.300000
# Habitat     65.0   61.683333  53.366667   82.10  61.866667   70.233333
#
#              October
# Employees
# EA         39.650000
# KR         56.700000
# KB         89.250000
# CP         29.250000
# MM         74.800000
# MC         91.700000
# Habitat    61.866667

# %%
df.loc['Water'] = df.loc[['CP', 'MM', 'MC']].mean()
df
# Out:
#                April         May       June        July     August  \
# Employees
# EA         65.000000   39.000000  53.950000   89.050000  48.750000
# KR         45.000000   50.850000  36.450000   53.550000  45.900000
# KB         85.000000   95.200000  69.700000  103.700000  90.950000
# CP         45.000000   28.800000  28.350000   27.450000  35.100000
# MM         85.000000  118.150000  51.000000  102.850000  98.600000
# MC         70.000000   74.900000  43.400000   82.600000  58.100000
# Habitat    65.000000   61.683333  53.366667   82.100000  61.866667
# Water      66.666667   73.950000  40.916667   70.966667  63.933333
#
#             September    October
# Employees
# EA          80.600000  39.650000
# KR          39.150000  56.700000
# KB          90.950000  89.250000
# CP          61.650000  29.250000
# MM         111.350000  74.800000
# MC          90.300000  91.700000
# Habitat     70.233333  61.866667
# Water       87.766667  65.250000

# %%
#Projected Monthly Utilization = If in month, projected utilization, else actual utilization
projected = pd.DataFrame(data=df.index, columns=['Employees']).set_index('Employees')
#Projected Yearly Utilization = weighted average of all utilization

# %%
projected
# Out:
# Empty DataFrame
# Columns: []
# Index: [EA, KR, KB, CP, MM, MC, Habitat, Water]

# %%
projected['April'] = df['April']
projected
# Out:
#                April
# Employees
# EA         65.000000
# KR         45.000000
# KB         85.000000
# CP         45.000000
# MM         85.000000
# MC         70.000000
# Habitat    65.000000
# Water      66.666667

# %%
df.mean(axis=1)
# Out:
# Employees
# EA         59.428571
# KR         46.800000
# KB         89.250000
# CP         36.514286
# MM         91.678571
# MC         73.000000
# Habitat    65.159524
# Water      67.064286
# dtype: float64

# %%
df.iloc[:,-1]
# Out:
# Employees
# EA         39.650000
# KR         56.700000
# KB         89.250000
# CP         29.250000
# MM         74.800000
# MC         91.700000
# Habitat    61.866667
# Water      65.250000
# Name: October, dtype: float64

# %%
for month in months:
    if month in df.columns:
        projected[month] = df[month]
    else:
        projected[month] = df.iloc[:,-1]
projected
# Out:
#                April         May       June        July     August  \
# Employees
# EA         65.000000   39.000000  53.950000   89.050000  48.750000
# KR         45.000000   50.850000  36.450000   53.550000  45.900000
# KB         85.000000   95.200000  69.700000  103.700000  90.950000
# CP         45.000000   28.800000  28.350000   27.450000  35.100000
# MM         85.000000  118.150000  51.000000  102.850000  98.600000
# MC         70.000000   74.900000  43.400000   82.600000  58.100000
# Habitat    65.000000   61.683333  53.366667   82.100000  61.866667
# Water      66.666667   73.950000  40.916667   70.966667  63.933333
#
#             September    October   November   December    January   February  \
# Employees
# EA          80.600000  39.650000  39.650000  39.650000  39.650000  39.650000
# KR          39.150000  56.700000  56.700000  56.700000  56.700000  56.700000
# KB          90.950000  89.250000  89.250000  89.250000  89.250000  89.250000
# CP          61.650000  29.250000  29.250000  29.250000  29.250000  29.250000
# MM         111.350000  74.800000  74.800000  74.800000  74.800000  74.800000
# MC          90.300000  91.700000  91.700000  91.700000  91.700000  91.700000
# Habitat     70.233333  61.866667  61.866667  61.866667  61.866667  61.866667
# Water       87.766667  65.250000  65.250000  65.250000  65.250000  65.250000
#
#                March
# Employees
# EA         39.650000
# KR         56.700000
# KB         89.250000
# CP         29.250000
# MM         74.800000
# MC         91.700000
# Habitat    61.866667
# Water      65.250000

# %%
projected.loc[:,'April': 'July']
# Out:
#                April         May       June        July
# Employees
# EA         65.000000   39.000000  53.950000   89.050000
# KR         45.000000   50.850000  36.450000   53.550000
# KB         85.000000   95.200000  69.700000  103.700000
# CP         45.000000   28.800000  28.350000   27.450000
# MM         85.000000  118.150000  51.000000  102.850000
# MC         70.000000   74.900000  43.400000   82.600000
# Habitat    65.000000   61.683333  53.366667   82.100000
# Water      66.666667   73.950000  40.916667   70.966667

# %%
projected_y = pd.DataFrame(data=df.index, columns=['Employees']).set_index('Employees')
for month in months:
    projected_y[month] = projected.loc[:,months[0]:month].mean(axis=1)
projected_y
# Out:
#                April         May       June     July     August  September  \
# Employees
# EA         65.000000   52.000000  52.650000  61.7500  59.150000  62.725000
# KR         45.000000   47.925000  44.100000  46.4625  46.350000  45.150000
# KB         85.000000   90.100000  83.300000  88.4000  88.910000  89.250000
# CP         45.000000   36.900000  34.050000  32.4000  32.940000  37.725000
# MM         85.000000  101.575000  84.716667  89.2500  91.120000  94.491667
# MC         70.000000   72.450000  62.766667  67.7250  65.800000  69.883333
# Habitat    65.000000   63.341667  60.016667  65.5375  64.803333  65.708333
# Water      66.666667   70.308333  60.511111  63.1250  63.286667  67.366667
#
#              October   November   December    January   February      March
# Employees
# EA         59.428571  56.956250  55.033333  53.495000  52.236364  51.187500
# KR         46.800000  48.037500  49.000000  49.770000  50.400000  50.925000
# KB         89.250000  89.250000  89.250000  89.250000  89.250000  89.250000
# CP         36.514286  35.606250  34.900000  34.335000  33.872727  33.487500
# MM         91.678571  89.568750  87.927778  86.615000  85.540909  84.645833
# MC         73.000000  75.337500  77.155556  78.610000  79.800000  80.791667
# Habitat    65.159524  64.747917  64.427778  64.171667  63.962121  63.787500
# Water      67.064286  66.837500  66.661111  66.520000  66.404545  66.308333

# %%
projected_y.T.plot()
