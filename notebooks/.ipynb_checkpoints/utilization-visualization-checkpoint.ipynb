# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import random

# %%
employees = ['EA', 'KR', 'KB', 'CP', 'MM', 'MC']
targets = [65, 45, 85, 45, 85, 70]
months = ['April', 'May', 'June', 'July', 'August', 'September', 'October', 'November',
         'December', 'January', 'February', 'March']

# %%
df = pd.DataFrame(list(zip(employees, targets)), columns=['Employees', months[0]])
df.set_index('Employees', inplace=True)
df
# Out:
#            April
# Employees
# EA            65
# KR            45
# KB            85
# CP            45
# MM            85
# MC            70

# %%
for month in months[1:-5]:
    random_data = [random.randrange(60,140)/100 for employee in df.index]
    df[month] = df['April'] * random_data
df
# Out:
#            April    May   June   July  August  September  October
# Employees
# EA            65  40.95  55.90  72.80   61.75      58.50    43.55
# KR            45  36.45  28.35  53.10   53.10      43.20    28.35
# KB            85  91.80  51.85  77.35   73.10      76.50    94.35
# CP            45  53.10  47.70  48.60   27.45      54.00    35.10
# MM            85  52.70  59.50  61.20   66.30     116.45   101.15
# MC            70  44.80  44.80  68.60   46.90      81.90    63.00

# %%
df.T.plot(legend=False)

# %%
habitat_avg = df.loc[['EA', 'KR', 'KB']].mean()
habitat_avg
# Out:
# April        65.000000
# May          56.400000
# June         45.366667
# July         67.750000
# August       62.650000
# September    59.400000
# October      55.416667
# dtype: float64

# %%
df.loc['Habitat'] = habitat_avg.T
df
# Out:
#            April    May       June   July  August  September     October
# Employees
# EA          65.0  40.95  55.900000  72.80   61.75      58.50   43.550000
# KR          45.0  36.45  28.350000  53.10   53.10      43.20   28.350000
# KB          85.0  91.80  51.850000  77.35   73.10      76.50   94.350000
# CP          45.0  53.10  47.700000  48.60   27.45      54.00   35.100000
# MM          85.0  52.70  59.500000  61.20   66.30     116.45  101.150000
# MC          70.0  44.80  44.800000  68.60   46.90      81.90   63.000000
# Habitat     65.0  56.40  45.366667  67.75   62.65      59.40   55.416667

# %%
df.loc['Water'] = df.loc[['CP', 'MM', 'MC']].mean()
df
# Out:
#                April    May       June       July     August   September  \
# Employees
# EA         65.000000  40.95  55.900000  72.800000  61.750000   58.500000
# KR         45.000000  36.45  28.350000  53.100000  53.100000   43.200000
# KB         85.000000  91.80  51.850000  77.350000  73.100000   76.500000
# CP         45.000000  53.10  47.700000  48.600000  27.450000   54.000000
# MM         85.000000  52.70  59.500000  61.200000  66.300000  116.450000
# MC         70.000000  44.80  44.800000  68.600000  46.900000   81.900000
# Habitat    65.000000  56.40  45.366667  67.750000  62.650000   59.400000
# Water      66.666667  50.20  50.666667  59.466667  46.883333   84.116667
#
#               October
# Employees
# EA          43.550000
# KR          28.350000
# KB          94.350000
# CP          35.100000
# MM         101.150000
# MC          63.000000
# Habitat     55.416667
# Water       66.416667

# %%
#Projected Monthly Utilization = If in month, projected utilization, else actual utilization
projected = pd.DataFrame(data=df.index, columns=['Employees']).set_index('Employees')
#Projected Yearly Utilization = weighted average of all utilization

# %%
projected
# Out:
# Empty DataFrame
# Columns: []
# Index: [EA, KR, KB, CP, MM, MC, Habitat, Water]

# %%
projected['April'] = df['April']
projected
# Out:
#                April
# Employees
# EA         65.000000
# KR         45.000000
# KB         85.000000
# CP         45.000000
# MM         85.000000
# MC         70.000000
# Habitat    65.000000
# Water      66.666667

# %%
df.mean(axis=1)
# Out:
# Employees
# EA         56.921429
# KR         41.078571
# KB         78.564286
# CP         44.421429
# MM         77.471429
# MC         60.000000
# Habitat    58.854762
# Water      60.630952
# dtype: float64

# %%
df.iloc[:,-1]
# Out:
# Employees
# EA          43.550000
# KR          28.350000
# KB          94.350000
# CP          35.100000
# MM         101.150000
# MC          63.000000
# Habitat     55.416667
# Water       66.416667
# Name: October, dtype: float64

# %%
for month in months:
    if month in df.columns:
        projected[month] = df[month]
    else:
        projected[month] = df.iloc[:,-1]
projected
# Out:
#                April    May       June       July     August   September  \
# Employees
# EA         65.000000  40.95  55.900000  72.800000  61.750000   58.500000
# KR         45.000000  36.45  28.350000  53.100000  53.100000   43.200000
# KB         85.000000  91.80  51.850000  77.350000  73.100000   76.500000
# CP         45.000000  53.10  47.700000  48.600000  27.450000   54.000000
# MM         85.000000  52.70  59.500000  61.200000  66.300000  116.450000
# MC         70.000000  44.80  44.800000  68.600000  46.900000   81.900000
# Habitat    65.000000  56.40  45.366667  67.750000  62.650000   59.400000
# Water      66.666667  50.20  50.666667  59.466667  46.883333   84.116667
#
#               October    November    December     January    February  \
# Employees
# EA          43.550000   43.550000   43.550000   43.550000   43.550000
# KR          28.350000   28.350000   28.350000   28.350000   28.350000
# KB          94.350000   94.350000   94.350000   94.350000   94.350000
# CP          35.100000   35.100000   35.100000   35.100000   35.100000
# MM         101.150000  101.150000  101.150000  101.150000  101.150000
# MC          63.000000   63.000000   63.000000   63.000000   63.000000
# Habitat     55.416667   55.416667   55.416667   55.416667   55.416667
# Water       66.416667   66.416667   66.416667   66.416667   66.416667
#
#                 March
# Employees
# EA          43.550000
# KR          28.350000
# KB          94.350000
# CP          35.100000
# MM         101.150000
# MC          63.000000
# Habitat     55.416667
# Water       66.416667

# %%
projected.loc[:,'April': 'July']
# Out:
#                April    May       June       July
# Employees
# EA         65.000000  40.95  55.900000  72.800000
# KR         45.000000  36.45  28.350000  53.100000
# KB         85.000000  91.80  51.850000  77.350000
# CP         45.000000  53.10  47.700000  48.600000
# MM         85.000000  52.70  59.500000  61.200000
# MC         70.000000  44.80  44.800000  68.600000
# Habitat    65.000000  56.40  45.366667  67.750000
# Water      66.666667  50.20  50.666667  59.466667

# %%
projected_y = pd.DataFrame(data=df.index, columns=['Employees']).set_index('Employees')
for month in months:
    projected_y[month] = projected.loc[:,months[0]:month].mean(axis=1)
projected_y
# Out:
#                April        May       June       July     August  September  \
# Employees
# EA         65.000000  52.975000  53.950000  58.662500  59.280000  59.150000
# KR         45.000000  40.725000  36.600000  40.725000  43.200000  43.200000
# KB         85.000000  88.400000  76.216667  76.500000  75.820000  75.933333
# CP         45.000000  49.050000  48.600000  48.600000  44.370000  45.975000
# MM         85.000000  68.850000  65.733333  64.600000  64.940000  73.525000
# MC         70.000000  57.400000  53.200000  57.050000  55.020000  59.500000
# Habitat    65.000000  60.700000  55.588889  58.629167  59.433333  59.427778
# Water      66.666667  58.433333  55.844444  56.750000  54.776667  59.666667
#
#              October   November   December    January   February      March
# Employees
# EA         56.921429  55.250000  53.950000  52.910000  52.059091  51.350000
# KR         41.078571  39.487500  38.250000  37.260000  36.450000  35.775000
# KB         78.564286  80.537500  82.072222  83.300000  84.304545  85.141667
# CP         44.421429  43.256250  42.350000  41.625000  41.031818  40.537500
# MM         77.471429  80.431250  82.733333  84.575000  86.081818  87.337500
# MC         60.000000  60.375000  60.666667  60.900000  61.090909  61.250000
# Habitat    58.854762  58.425000  58.090741  57.823333  57.604545  57.422222
# Water      60.630952  61.354167  61.916667  62.366667  62.734848  63.041667

# %%
projected_y.T.plot()

# %%
projected_y.loc[['Habitat', 'Water'],:].T.plot()

# %%
data = projected_y.T
plt.style.use('seaborn-whitegrid')

water_color='blue'
habitat_color='orange'

fig, ax = plt.subplots(figsize=[12,6])
ax.plot(data['Habitat'], color=habitat_color, linewidth=3, alpha=.85)
ax.plot(data['Water'], color=water_color, linewidth=3, alpha=.85)
ax.plot(data[['EA','KR','KB']], color=habitat_color,alpha=.4)
ax.plot(data[['CP','MM','MC']], color=water_color, alpha=.4)

# ax.axvline(6, color='grey', alpha=.4, linewidth=3)

#Styling
# plt.suptitle('Utilization by Practice Area', y=0.97, fontsize=14)
plt.title('Are we on track to meet our utilization target?', loc='right', fontsize=14)

plt.ylim(0,120)

ax.yaxis.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)

#Labels
habitat_value = data.loc[months[-1], 'Habitat']
water_value = data.loc[months[-1], 'Water']
plt.text(11.5, habitat_value, f'Habitat ({int(habitat_value)}%)', color=habitat_color,
        fontsize=12)
plt.text(11.5, water_value, f'Water ({int(water_value)}%)', color=water_color,
        fontsize=12)
for employee in employees:
    employee_value=data.loc[months[-1], employee]
    plt.text(11,employee_value,employee)

plt.tight_layout()

plt.show()
