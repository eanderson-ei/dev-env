# %% [markdown]
# ## Setting up a widget

# %%
#Had to pip install nodejs to get widgets to display in browser

from ipywidgets import widgets
slider = widgets.IntSlider(value=50)
slider
# Out:
# IntSlider(value=50)

# %% [markdown]
# ## Editing a widget's value

# %%
slider.value=100

# %%
slider.value
# Out:
# 100

# %% [markdown]
# ## Listenting to Changes

# %%
from ipywidgets import HTML
text = HTML("The slider's value is <b>{}<b>".format(slider.value))
text
# Out:
# HTML(value="The slider's value is <b>100<b>")

# %%
def myfunc(change):
    text.value = "The slider's value is <b>{}<b>".format(slider.value)
    
slider.observe(myfunc, 'value')

# %% [markdown]
# ## Plotting (see also ipyleaflet)

# %%
import numpy as np

from sklearn import linear_model
from bqplot import LinearScale, Scatter, Figure
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-630091d580e8> in <module>
#       1 import numpy as np
#       2
# ----> 3 from sklearn import linear_model
#       4 from bqplot import LinearScale, Scatter, Figure
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# Styles
line_style = {'colors': ['magenta'], 'stroke_width':3}
scatter_style = {'colors': ['white'], 'stroke':'black'}

# %%
x = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])
y = np.dot(x, np.array([1, 2])) + 3
print(x,y)
# Out:
# [[1 1]
#  [1 2]
#  [2 2]
#  [2 3]] [ 6  8  9 11]

# %%
regr = linear_model.LinearRegression()
regr.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pred = regr.predict(x)
print(pred)
# Out:
# [ 6.  8.  9. 11.]

# %%
# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

def f(m, b):
    plt.figure(2)
    x = np.linspace(-10, 10, num=1000)
    plt.plot(x, m * x + b)
    plt.ylim(-5, 5)
    plt.show()

interactive_plot = interactive(f, m=(-2.0, 2.0), b=(-3, 3, 0.5))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.0, description='m', max=2.0, min=-2.0), FloatSlider(value=0.0, descr…

# %%
widgets.Text(value = 'Hellow World!')
# Out:
# Text(value='Hellow World!')

# %%
a = widgets.FloatText()
b = widgets.FloatSlider()
from IPython.display import display

# %%
display(a,b)
mylink = widgets.jslink((a, 'value'), (b, 'value'))
# Out:
# FloatText(value=0.0)
# FloatSlider(value=0.0)

# %% [markdown]
# ## Leaflet

# %%
from ipywidgets import HTML
from ipyleaflet import Map, DrawControl, Marker, Popup
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-b6be18157e93> in <module>
#       1 from ipywidgets import HTML
# ----> 2 from ipyleaflet import Map, DrawControl, Marker, Popup
#
# ModuleNotFoundError: No module named 'ipyleaflet'

# %%
# !jupyter nbextension enable --py --sys-prefix ipyleaflet
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Erik\Anaconda3\envs\dev-env\Scripts\jupyter-nbextension-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\Users\Erik\Anaconda3\envs\dev-env\lib\site-packages\jupyter_core\application.py", line 254, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "C:\Users\Erik\Anaconda3\envs\dev-env\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\Erik\Anaconda3\envs\dev-env\lib\site-packages\notebook\nbextensions.py", line 980, in start
#     super().start()
#   File "C:\Users\Erik\Anaconda3\envs\dev-env\lib\site-packages\jupyter_core\application.py", line 243, in start
#     self.subapp.start()
#   File "C:\Users\Erik\Anaconda3\envs\dev-env\lib\site-packages\notebook\nbextensions.py", line 888, in start
#     self.toggle_nbextension_python(self.extra_args[0])
# ...

# %%
myMap = ipyleaflet.Map(center=[40.5, -107.5], zoom = 10)
dc = DrawControl(circle={'shapeOptions':{'color':'#0000FF'}})
myMap.add_control(dc)
myMap
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: click_handler() got an unexpected keyword argument 'event'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: click_handler() got an unexpected keyword argument 'event'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: click_handler() got an unexpected keyword argument 'event'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ...

# %%
marker = Marker(location=[40.5, -107.5])

# %%
myMap.add_layer(marker)

# %%
message = HTML()
message.value = "Hello <b>World</b>"
message.placeholder = "Placeholder"
message.description = "Description"

# Popup associated to a layer
marker.popup = message

# %%
marker.location
# Out:
# [40.42162802698694, -107.39624021574856]

# %%
def click_handler(marker):
    message.value = "Hello World 2"
marker.on_click(click_handler)
