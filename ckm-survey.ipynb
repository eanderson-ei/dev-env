# %%
import pandas as pd
import plotly.graph_objects as go

# %%
df = pd.read_csv(r'C:\Users\Erik\OneDrive - Environmental Incentives\Downloads\ckm-survey.csv')
df.describe()
# Out:
#               Timestamp                Email Address       Name  \
# count                15                           15         15
# unique               15                           15         15
# top     1/27/2021 20:02  elauck@enviroincentives.com  Liz Lauck
# freq                  1                            1          1
#
#        Please indicate your highest level of education  \
# count                                               15
# unique                                              12
# top                                                 MA
# freq                                                 3
#
#        Please provide the number years of professional communications experience you have.  \
# count                                                  15
# unique                                                 13
# top                                                     5
# freq                                                    3
#
# ...

# %% [markdown]
# profile = ProfileReport(df, title="CKM Survey Profiling Report", explorative=True)

# %% [markdown]
# profile.to_file("ckm-survey-report.html")
